# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Blu-Ray\Documents\python_pandnas\netflix_titles.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # 1.head

# %%
data.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# # 2.tail

# %%
data.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %% [markdown]
# # 3.shape

# %%
data.shape
# Out:
# (8807, 12)

# %% [markdown]
# # 4.size

# %%
data.size
# Out:
# 105684

# %% [markdown]
# # 5.columns

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # 6.dtypes

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # 6.info

# %%
data.info
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %% [markdown]
# # Cleaning Data
#
# # Q1)modify the data by Inserting all the data recorded starting from 2010 until 2021?

# %%
data=data[data['release_year'] > 2009]

# %%
data
# Out:
#      show_id     type                  title                 director  \
# 0         s1    Movie   Dick Johnson Is Dead          Kirsten Johnson
# 1         s2  TV Show          Blood & Water                      NaN
# 2         s3  TV Show              Ganglands          Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                      NaN
# 4         s5  TV Show           Kota Factory                      NaN
# ...      ...      ...                    ...                      ...
# 8798   s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# 8800   s8801  TV Show     Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie                Zinzana          Majid Al Ansari
# 8803   s8804  TV Show            Zombie Dumb                      NaN
# 8806   s8807    Movie                 Zubaan              Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %% [markdown]
# # Q2)Is there any duplicate record in this dataset?if yes, then remove the duplicate records

# %%
data[data.duplicated()]  #Answer: there are never duplicated records
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # Visualizing the data and answering the requested questions
#
#
# # Q1)Is there any null value pesent in any column?Show with Heat-map

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8798    False  False  False     False  False    False       False
# 8800    False  False  False      True  False    False       False
# 8801    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2451
# cast             793
# country          784
# date_added         7
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Q2)# For 'Anthony Jeselnik: Thoughts and Prayers', What is the Show Id and Who is the Director Of this show?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[data['title'].isin(['Anthony Jeselnik: Thoughts and Prayers'])] #To show all records of a particular item in any column
# Out:
#      show_id   type                                   title    director  \
# 5890   s5891  Movie  Anthony Jeselnik: Thoughts and Prayers  Adam Dubin
#
#                   cast        country        date_added  release_year rating  \
# 5890  Anthony Jeselnik  United States  October 16, 2015          2015  TV-MA
#
#      duration        listed_in  \
# 5890   59 min  Stand-Up Comedy
#
#                                             description
# 5890  There's no subject too dark as the comedian sk...

# %%
data[data['title'].str.contains('Anthony Jeselnik: Thoughts and Prayers')] #To show all records of a particular str in any column
# Out:
#      show_id   type                                   title    director  \
# 5890   s5891  Movie  Anthony Jeselnik: Thoughts and Prayers  Adam Dubin
#
#                   cast        country        date_added  release_year rating  \
# 5890  Anthony Jeselnik  United States  October 16, 2015          2015  TV-MA
#
#      duration        listed_in  \
# 5890   59 min  Stand-Up Comedy
#
#                                             description
# 5890  There's no subject too dark as the comedian sk...

# %% [markdown]
# # Q3)In which Year highest number of the TV shows & Movies were released?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# Name: count, dtype: int64

# %%
data['release_year'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# # Q4) How many TV shows & Movies are in the data set? show with bar graph

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      4978
# TV Show    2494
# Name: type, dtype: int64

# %%
sns.countplot(x='type', data=data)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# # Q5) show all  Movies that was released in 2015

# %%
data[(data['type'] == 'Movie') & (data['release_year']== 2015)]
# Out:
#      show_id   type                  title           director  \
# 116     s117  Movie                 Dhanak    Nagesh Kukunoor
# 133     s134  Movie                Chappie     Neill Blomkamp
# 141     s142  Movie             Extraction   Steven C. Miller
# 173     s174  Movie  Snervous Tyler Oakley           Amy Rice
# 257     s258  Movie       O Kadhal Kanmani        Mani Ratnam
# ...      ...    ...                    ...                ...
# 8779   s8780  Movie          Yes or No 2.5  Kirati Nakintanon
# 8784   s8785  Movie   Yoko and His Friends                NaN
# 8788   s8789  Movie           You Carry Me         Ivona Juka
# 8801   s8802  Movie                Zinzana    Majid Al Ansari
# 8806   s8807  Movie                 Zubaan        Mozez Singh
#
#                                                    cast  \
# 116   Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...
# 133   Sharlto Copley, Hugh Jackman, Sigourney Weaver...
# ...

# %% [markdown]
# # Q6) show only the titles of all TV shows that were released in india only

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data[(data['type'] == 'TV Show') & (data['country']== 'India')] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 78, dtype: object

# %% [markdown]
# # Q7) show top 10 Directors who gave the highest number of TV shows & Movies to Netflix?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data["director"].value_counts().head(10)
# Out:
# director
# Raúl Campos, Jan Suter    18
# Rajiv Chilaka             17
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Jay Chapman               12
# Cathy Garcia-Molina       11
# Don Michael Paul          10
# Hakan Algül                8
# Lance Bangs                8
# Name: count, dtype: int64

# %% [markdown]
# # Q8)Show all the Records, where "category is Movie and listed_in Documentaries" or "Country is UK"?

# %%
data[((data['type']=='Movie') & (data['listed_in']=='Documentaries')) | (data['country']=='United Kingdom') ]
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 32       s33  TV Show                  Sex Education              NaN
# 45       s46    Movie         My Heroes Were Cowboys      Tyler Greco
# 65       s66  TV Show                   Numberblocks              NaN
# ...      ...      ...                            ...              ...
# 8740   s8741  TV Show                    Wild Alaska              NaN
# 8741   s8742  TV Show                    Wild Arabia              NaN
# 8744   s8745    Movie                       Williams  Morgan Matthews
# 8758   s8759  TV Show         World's Busiest Cities              NaN
# 8786   s8787    Movie                   You Can Tutu      James Brown
#
#                                                    cast         country  \
# ...

# %% [markdown]
# # Q9)In how many movies/shows, Patrick Wilson was cast?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
new_data=data.dropna()

# %%
new_data
# Out:
#      show_id     type                          title                 director  \
# 8         s9  TV Show  The Great British Baking Show          Andy Devonshire
# 9        s10    Movie                   The Starling           Theodore Melfi
# 12       s13    Movie                   Je Suis Karl      Christian Schwochow
# 27       s28    Movie                      Grown Ups             Dennis Dugan
# 28       s29    Movie                     Dark Skies            Scott Stewart
# ...      ...      ...                            ...                      ...
# 8791   s8792    Movie                    Young Adult            Jason Reitman
# 8794   s8795    Movie                         اشتباك             Mohamed Diab
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8801   s8802    Movie                        Zinzana          Majid Al Ansari
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
new_data[new_data['cast'].str.contains('Patrick Wilson')]
# Out:
#      show_id   type              title               director  \
# 1118   s1119  Movie          Insidious              James Wan
# 1283   s1284  Movie      The Conjuring              James Wan
# 1284   s1285  Movie    The Conjuring 2              James Wan
# 2419   s2420  Movie      Big Stone Gap       Adriana Trigiani
# 3450   s3451  Movie  In the Tall Grass        Vincenzo Natali
# 6042   s6043  Movie   A Kind of Murder           Andy Goddard
# 8312   s8313  Movie        The Founder       John Lee Hancock
# 8345   s8346  Movie   The Hollow Point  Gonzalo López-Gallego
# 8791   s8792  Movie        Young Adult          Jason Reitman
#
#                                                    cast  \
# 1118  Patrick Wilson, Rose Byrne, Lin Shaye, Ty Simp...
# 1283  Vera Farmiga, Patrick Wilson, Lili Taylor, Ron...
# 1284  Patrick Wilson, Vera Farmiga, Madison Wolfe, F...
# 2419  Ashley Judd, Patrick Wilson, Whoopi Goldberg, ...
# 3450  Patrick Wilson, Laysla De Oliveira, Avery Whit...
# ...

# %% [markdown]
# # Q10) what are the different Ratings defined by by netflix?

# %%
data['rating'].nunique()
# Out:
# 17

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Q11) How many movies got the 'TV-14' rating, in Canada?

# %%
data[(data['type']=="Movie") & (data['rating']=='TV-14') & (data['country']=='Canada') ]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
data[(data['type']=="Movie") & (data['rating']=='TV-14') & (data['country']=='Canada') ].shape
# Out:
# (13, 12)

# %% [markdown]
# # Q12) How many movies got the 'R' rating, after year 2018?

# %%
data[(data['type']=="Movie") & (data['rating']=='R') & (data['release_year']>2018) ]
# Out:
#      show_id   type                        title               director  \
# 81       s82  Movie                         Kate  Cedric Nicolas-Troyan
# 214     s215  Movie  SAS: Rise of the Black Swan         Magnus Martens
# 247     s248  Movie                   Sweet Girl   Brian Andrew Mendoza
# 363     s364  Movie                    The Vault        Jaume Balagueró
# 437     s438  Movie                   Cosmic Sin           Edward Drake
# ...      ...    ...                          ...                    ...
# 6286   s6287  Movie           Berlin, I Love You                    NaN
# 6623   s6624  Movie                       Domino         Brian De Palma
# 6682   s6683  Movie            Elizabeth Harvest    Sebastian Gutierrez
# 6713   s6714  Movie              Everybody Knows         Asghar Farhadi
# 7950   s7951  Movie                   Saving Zoë        Jeffrey G. Hunt
#
#                                                    cast  \
# ...

# %% [markdown]
# # Q13) Divide the duration column into two columns "minute" and "Unit"

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '9 Seasons',
#        '104 min', '127 min', '4 Seasons', '67 min', '94 min', '5 Seasons',
#        '61 min', '103 min', '97 min', '106 min', '111 min', '3 Seasons',
#        '110 min', '105 min', '96 min', '23 min', '115 min', '6 Seasons',
#        '102 min', '85 min', '113 min', '13 min', '182 min', '48 min',
#        '145 min', '93 min', '147 min', '87 min', '95 min', '92 min',
#        '80 min', '117 min', '128 min', '119 min', '114 min', '99 min',
#        '63 min', '121 min', '108 min', '100 min', '82 min', '88 min',
#        '118 min', '120 min', '83 min', '112 min', '86 min', '125 min',
#        '107 min', '124 min', '136 min', '133 min', '142 min', '70 min',
#        '122 min', '84 min', '140 min', '78 min', '7 Seasons', '64 min',
#        '59 min', '101 min', '98 min', '139 min', '135 min', '69 min',
#        '116 min', '148 min', '76 min', '138 min', '81 min', '143 min',
# ...

# %%
data[["Minutes","Unit"]] = data['duration'].str.split(' ',expand=True)
# Out:
# C:\Users\Blu-Ray\AppData\Local\Temp\ipykernel_23628\4171603126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Minutes","Unit"]] = data['duration'].str.split(' ',expand=True)
# C:\Users\Blu-Ray\AppData\Local\Temp\ipykernel_23628\4171603126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Minutes","Unit"]] = data['duration'].str.split(' ',expand=True)

# %%
data
# Out:
#      show_id     type                  title                 director  \
# 0         s1    Movie   Dick Johnson Is Dead          Kirsten Johnson
# 1         s2  TV Show          Blood & Water                      NaN
# 2         s3  TV Show              Ganglands          Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                      NaN
# 4         s5  TV Show           Kota Factory                      NaN
# ...      ...      ...                    ...                      ...
# 8798   s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# 8800   s8801  TV Show     Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie                Zinzana          Majid Al Ansari
# 8803   s8804  TV Show            Zombie Dumb                      NaN
# 8806   s8807    Movie                 Zubaan              Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %% [markdown]
# # Q14) What is the maximum duration of a Movie/Show on netflix?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description Minutes     Unit
# 0  As her father nears the end of his life, filmm...      90      min
# 1  After crossing paths at a party, a Cape Town t...       2  Seasons

# %%
data['Minutes']=data['Minutes'].apply(pd.to_numeric)
# Out:
# C:\Users\Blu-Ray\AppData\Local\Temp\ipykernel_23628\1938982467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Minutes']=data['Minutes'].apply(pd.to_numeric)

# %%
data['Minutes'].max()
# Out:
# 312.0

# %%
data
# Out:
#      show_id     type                  title                 director  \
# 0         s1    Movie   Dick Johnson Is Dead          Kirsten Johnson
# 1         s2  TV Show          Blood & Water                      NaN
# 2         s3  TV Show              Ganglands          Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                      NaN
# 4         s5  TV Show           Kota Factory                      NaN
# ...      ...      ...                    ...                      ...
# 8798   s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# 8800   s8801  TV Show     Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie                Zinzana          Majid Al Ansari
# 8803   s8804  TV Show            Zombie Dumb                      NaN
# 8806   s8807    Movie                 Zubaan              Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %% [markdown]
# # Q16) which the individual country has the Highest number No of Tv Shows?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  Minutes     Unit
# 0  As her father nears the end of his life, filmm...     90.0      min
# 1  After crossing paths at a party, a Cape Town t...      2.0  Seasons

# %%
data_tvshow=data[data['type'] == "TV Show"]

# %%
data_tvshow.country.value_counts()
# Out:
# country
# United States                                    703
# United Kingdom                                   200
# South Korea                                      155
# Japan                                            142
# India                                             78
#                                                 ...
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United Kingdom, China                              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 188, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# country
# United States    703
# Name: count, dtype: int64

# %% [markdown]
# # Q17) How can the dataset ve sorted  by release_year?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  Minutes     Unit
# 0  As her father nears the end of his life, filmm...     90.0      min
# 1  After crossing paths at a party, a Cape Town t...      2.0  Seasons

# %%
data.sort_values(by = 'release_year')
# Out:
#      show_id     type                                     title  \
# 2745   s2746    Movie                              The Runaways
# 6857   s6858  TV Show                            Glowing Embers
# 6662   s6663    Movie                                    Easy A
# 6433   s6434    Movie  Cats & Dogs: The Revenge of Kitty Galore
# 8643   s8644    Movie                                     Twice
# ...      ...      ...                                       ...
# 857     s858  TV Show                              The Neighbor
# 855     s856  TV Show            Jurassic World Camp Cretaceous
# 854     s855    Movie              Creating an Army of the Dead
# 577     s578  TV Show                           Masameer County
# 703     s704  TV Show                                  The Gift
#
#                director                                               cast  \
# 2745  Floria Sigismondi  Kristen Stewart, Dakota Fanning, Michael Shann...
# ...

# %%
data.sort_values(by = 'release_year' , ascending = False).head(10)
# Out:
#      show_id     type                                              title  \
# 1394   s1395  TV Show                                           Spycraft
# 848     s849  TV Show                                     Master of None
# 835     s836  TV Show                                               Eden
# 836     s837    Movie                                          Ghost Lab
# 837     s838  TV Show                                           Ragnarok
# 838     s839    Movie                              Soy Rada: Serendipity
# 840     s841    Movie                        Baggio: The Divine Ponytail
# 841     s842    Movie                             Gatao - The Last Stray
# 842     s843  TV Show  High on the Hog: How African American Cuisine ...
# 844     s845    Movie                               Nail Bomber: Manhunt
#
#                  director                                               cast  \
# 1394                  NaN                                                NaN
# ...

# %% [markdown]
# # Q18)Find all the instances where:
#     Type is 'Movie' and listed_in 'dramas'
#     or
#     Type is 'TV_Show' and listed_in 'Kids_TV'

# %%
data[((data['type']=='Movie') & (data['listed_in'].str.contains('Dramas'))) | ((data['type']=='TV Show') & (data['listed_in'].str.contains(' Kids\' TV')))]
# Out:
#      show_id     type                           title  \
# 9        s10    Movie                    The Starling
# 12       s13    Movie                    Je Suis Karl
# 30       s31    Movie                 Ankahi Kahaniya
# 35       s36    Movie  The Father Who Moves Mountains
# 36       s37    Movie                  The Stronghold
# ...      ...      ...                             ...
# 8794   s8795    Movie                          اشتباك
# 8795   s8796  TV Show                 Yu-Gi-Oh! Arc-V
# 8798   s8799    Movie                        Zed Plus
# 8801   s8802    Movie                         Zinzana
# 8806   s8807    Movie                          Zubaan
#
#                                                director  \
# 9                                        Theodore Melfi
# 12                                  Christian Schwochow
# 30    Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# 35                                         Daniel Sandu
# ...

# %%
 data[(data['type']=='TV Show') & (data['listed_in'].str.contains(' Kids\' TV'))]
# Out:
#      show_id     type                                              title  \
# 85       s86  TV Show                Pokémon Master Journeys: The Series
# 98       s99  TV Show                          Octonauts: Above & Beyond
# 540     s541  TV Show                                    The Worst Witch
# 565     s566  TV Show                           Bureau of Magical Things
# 590     s591  TV Show                                Sailor Moon Crystal
# 925     s926  TV Show                                 Angelina Ballerina
# 1025   s1026  TV Show                             Bakugan: Geogan Rising
# 1049   s1050  TV Show                                         Ricky Zoom
# 1206   s1207  TV Show                                         Zero Chill
# 1235   s1236  TV Show                       Pokémon Journeys: The Series
# 1506   s1507  TV Show                                    Shaun the Sheep
# 1508   s1509  TV Show                                         Timmy Time
# ...
